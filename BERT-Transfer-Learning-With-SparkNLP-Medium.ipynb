# %% [markdown]
# ##Goal: Train and deploy a NLP classification model on labeled text data via Spark NLP transfer learning on BERT (Bidirectional Encoder Representations from Transformers) language model

# %% [markdown]
# **Source dataset**: https://www.kaggle.com/datasets/reihanenamdari/mental-health-corpus?resource=download

# %% [markdown]
# **Dataset description**: "The Mental Health Corpus is a collection of texts related to people with anxiety, depression, and other mental health issues. The corpus consists of two columns: one containing the comments, and the other containing labels indicating whether the comments are considered poisonous or not. The corpus can be used for a variety of purposes, such as sentiment analysis, toxic language detection, and mental health language analysis. The data in the corpus may be useful for researchers, mental health professionals, and others interested in understanding the language and sentiment surrounding mental health issues."

# %% [markdown]
# ## Databricks cluster config considerations see here:

# %% [markdown]
# https://nlp.johnsnowlabs.com/docs/en/production-readiness

# %% [markdown]
# ## Confirm Spark NLP is available

# %%
spark.sparkContext.getConf().get('spark.jars.packages')
# Out:
# Out[5]: 'com.johnsnowlabs.nlp:spark-nlp_2.12:4.2.8'

# %% [markdown]
# ## Starting of Spark Session

# %%
import sparknlp
from pyspark.ml import Pipeline
from sparknlp.annotator import *
from sparknlp.common import *
from sparknlp.base import *

spark = sparknlp.start()

print("Version of SparkNLP:", sparknlp.version())
print("Version of Spark :", spark.version)
# Out:
# Version of SparkNLP: 4.2.8
# Version of Spark : 3.3.1

# %% [markdown]
# ## Loading and Reading the DataSet

# %%
from pyspark.sql.functions import *

df = spark.read.table('default.mental_health') \
.withColumnRenamed('label', 'category') \
.select("category", "text") \
.withColumn("category", when(col("category") == 1, "depressed") \
.otherwise("not_depressed"))

df.groupBy("category").count().show()
# Out:
# +-------------+-----+
# |     category|count|
# +-------------+-----+
# |not_depressed|14139|
# |    depressed|13838|
# +-------------+-----+

# %%
df.show(50, truncate=100)
# Out:
# +-------------+----------------------------------------------------------------------------------------------------+
# |     category|                                                                                                text|
# +-------------+----------------------------------------------------------------------------------------------------+
# |not_depressed|dear american teens question dutch person heard guys get way easier things learn age us sooooo th...|
# |    depressed|nothing look forward lifei dont many reasons keep going feel like nothing keeps going next day ma...|
# |not_depressed|music recommendations im looking expand playlist usual genres alt pop minnesota hip hop steampunk...|
# |    depressed|im done trying feel betterthe reason im still alive know mum devastated ever killed myself ever p...|
# |    depressed|worried  year old girl subject domestic physicalmental housewithout going lot know girl know girl...|
# |    depressed|hey rredflag sure right place post this goes  im currently student intern sandia national labs wo...|
# |not_depressed|feel like someone needs hear tonight feeling right think cant anything people keep puting listen ...|
# |    depressed|deserve liveif died right noone would carei real friendsi always start conversations get dry resp...|
# |    depressed|                         feels good ive set dateim killing friday nice finally know im gonna it bye |
# |    depressed|live guiltok made stupid random choice  its getting me basically molested relative super erratic ...|
# |not_depressed|                 excercise motivated ngl cant wait get shape know gonna overnight im happy right now|
# |not_depressed|                               know youd rather laid big booty body hella positive cuz got big booty|
# |not_depressed|                                                                       even time fuck  supposed mean|
# |not_depressed|usual hollywood stereotyped everyone movie but one classic  uptight white collar banker russian w...|
# |not_depressed|think it nearly unbelievable film could made death penalty one worlds controversial topics offend...|
# |not_depressed|                                                                       trying rd time k krma special|
# |not_depressed|guy coming sure wear f hey guy friend coming tomorrow im excited im sure wear ive known since mid...|
# |not_depressed|one best episodes entire xfiles series creepy beyond words tension suspense episode well executed...|
# |    depressed|good byehey you know sure hell know me goodbye probably mean anything you plus bother read rules ...|
# |    depressed|                tried put sugar coffee back spoon happy monday everyonestay safe sunflowers one days|
# |    depressed|sure leave noteso im struggling place leave note obvious family die find read it especially inclu...|
# |not_depressed|                          bruh wish dumb  years ago ignorance bliss im aware fucked people enjoyable|
# |    depressed|want die even tho feels like dead yearshello everyone want tell u depression  loneliness general ...|
# |    depressed|im barely holding oni night prolonged panic attack get lot one sustained take loraz butbit isnt w...|
# |not_depressed|im warn you please hear out hello getting straight point searching friends know basic daily stuff...|
# |    depressed|                                               me think think lost matter point never felt want much|
# |not_depressed|got told im lot prettier person girl talked lot video chat idk feel it good thing think ugly vide...|
# |    depressed|every success ever life come extremely lucky high school applied one college early got in senior ...|
# |    depressed|                                              emptynever know time gonna up id admit mental ward im |
# |    depressed|                                               bad memories keep playing headover again thought this|
# |not_depressed|wish people family owned cats dogs like  cousins million nd amp rd cousins like  aunts uncles non...|
# |not_depressed|                                  got friends prank call yoooooo yall got numbers boys prank call us|
# |not_depressed|discovered film love it right mix fast moving story entertaining characters hilarious moments but...|
# |    depressed|redflag vegas final chapteri know lame op deliver especially know right begging pull figurative t...|
# |    depressed|cant go oni wanna kill ive gone shit cant bare life anymore im always shouted main person complai...|
# |not_depressed|im probably going get body pillow printed plain white body pillow need hug something im crying sleep|
# |    depressed|cant cope please helpso im bi  cant cope mum hates parents going disown find im bi theyve made cl...|
# |not_depressed|                                    finally upgarded grandma bought new phone beneath using s yearsd|
# |not_depressed|                                                                                          eat decide|
# |    depressed|giving thoughtsive wanting od since  im almost  getting worse started wasnt bad easy distract tho...|
# |    depressed|im fine lost good longtime friend addiction and directly od morning let world get you seek help p...|
# |    depressed|would stay sign things would get better things bad last three years keep getting worse tough feel...|
# |    depressed| slept  hours want relapse cannot stop thinking abt got raped everytbint bad parente abuse me hoo...|
# |    depressed|remember always saying cannot wait til  kid  now nothing changed work manage finish school slippe...|
# |    depressed|start feeling anything better wth anybody know long citalopram eight years  mgs daily feedback ap...|
# |    depressed|starting feel like endive married  years give take last  wife affair guy try leave move on keeps ...|
# |not_depressed|pls stop please stop posts ask crush kinda weird im pretty sure reddit dating app text something ...|
# |    depressed|wanna im sure howso uh yeah really wanna myself im tired everything need permanent solution point...|
# |not_depressed|          keep ya head bro girls call ugly want remember go   swipe makeup remover keep ya head king|
# |    depressed|done misery tired tired going bed every night tired waking every morning tired listening fucking ...|
# +-------------+----------------------------------------------------------------------------------------------------+
# only showing top 50 rows

# %% [markdown]
# ## Split the dataset into training and testing sets

# %%
train_text, test_text = df.randomSplit([0.8, 0.2], seed = 12345)

# %% [markdown]
# ## Start MLflow for experiment and model tracking

# %%
import mlflow
from mlflow.models import Model, infer_signature, ModelSignature

mlflow_run = mlflow.start_run()

# Signature
signature = infer_signature(test_text)

# %% [markdown]
# ## Classification with `BertSentenceEmbeddings`

# %% [markdown]
# Using **BERT LaBSE Sentence Embeddings** (https://nlp.johnsnowlabs.com/2020/09/23/labse.html) and **ClassifierDLApproach** (https://nlp.johnsnowlabs.com/api/com/johnsnowlabs/nlp/annotators/classifier/dl/ClassifierDLApproach)

# %%
document = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

embeddings = BertSentenceEmbeddings\
    .pretrained("labse", "xx") \
    .setInputCols(["document"])\
    .setOutputCol("sentence_embeddings")

classsifierdl = ClassifierDLApproach()\
   .setInputCols(["sentence_embeddings"])\
   .setOutputCol("class")\
   .setLabelColumn("category")\
   .setMaxEpochs(10)\
   .setEnableOutputLogs(True)

nlp_pipeline_bert = Pipeline(
    stages=[document, 
            embeddings,
            classsifierdl])
# Out:
# labse download started this may take some time.
# Approximate size to download 1.7 GB
# [OK!]

# %% [markdown]
# #### Train model on training set... depending on cluster configuration this can take some time (30 minutes to an hour)

# %%
classification_model_bert = nlp_pipeline_bert.fit(train_text)

# %% [markdown]
# #### Log the model in MLflow and build a reference to the model URI

# %%
import pandas as pd

input_example = pd.DataFrame([{"index": 0, "text": "I'm lost in the darkness and can't find my way out."}, {"index": 1, "text": "Life is full of exciting possibilities!"}])

conda_env = {
    'channels': ['conda-forge'],
    'dependencies': [
        'python=3.9.5',
        {
            "pip": [
              'pyspark==3.1.2',
              'mlflow<3,>=2.1',
              'spark-nlp==4.2.8'
            ]
        }
    ],
    'name': 'mlflow-env'
}

model_name = "BERT_NLP_mental_health_classification_model"

mlflow.spark.log_model(classification_model_bert, model_name, conda_env=conda_env, signature=signature, input_example=input_example)

mlflow.log_artifacts("com.johnsnowlabs.nlp:spark-nlp_2.12:4.2.8")

mlflow.end_run()

mlflow_model_uri = "runs:/{}/{}".format(mlflow_run.info.run_id, model_name)

display(mlflow_model_uri)
# Out:
# /databricks/python/lib/python3.9/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 'runs:/96ddf7167cd748b68e38af22cd5cc54b/BERT_NLP_mental_health_classification_model'

# %% [markdown]
# #### Load the logged model back in from Experiments (takes a while)

# %%
loaded_model = mlflow.spark.load_model(mlflow_model_uri)
# Out:
# 2023/02/06 20:58:55 INFO mlflow.spark: 'runs:/96ddf7167cd748b68e38af22cd5cc54b/BERT_NLP_mental_health_classification_model' resolved as 'dbfs:/databricks/mlflow-tracking/507237834301906/96ddf7167cd748b68e38af22cd5cc54b/artifacts/BERT_NLP_mental_health_classification_model'

# %% [markdown]
# #### Run predictions on test dataset (also takes some time to process)

# %%
df_bert = loaded_model.transform(test_text).select("category", "text", "class.result").toPandas()

# %% [markdown]
# #### View some 'depressed' predictions

# %%
df_bert_depressed = df_bert[df_bert['category'] == 'depressed']
df_bert_depressed.head(50)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>category</th>
#       <th>text</th>
#       <th>result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>depressed</td>
#       <td>mg xanax thinking taking all know im even po...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>depressed</td>
#       <td>college graduate make k year live atlanta kid...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>depressed</td>
#       <td>commit redflag mondaymy situation pity asked ...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>depressed</td>
#       <td>days ago redflag failedthe past  days despera...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>depressed</td>
#       <td>dead every fucking second day good enough sta...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>depressed</td>
#       <td>extremely depressed struggle feel sense impor...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>depressed</td>
#       <td>feel bad cant pass way idk want cry time feel...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>depressed</td>
#       <td>hours i hopeim indecisive bastard first  jan ...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>depressed</td>
#       <td>male college student need help badlyi really ...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>depressed</td>
#       <td>malemy mum alcoholic mum means mom england dr...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>depressed</td>
#       <td>mg benzo  ml  vodka kill meplease answer yes ...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>depressed</td>
#       <td>much want scale</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>depressed</td>
#       <td>number mental breakdowns  number near mental ...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>depressed</td>
#       <td>pleaseprobably gonna kill soon im stranded sm...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>depressed</td>
#       <td>ready give up want get away this</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>depressed</td>
#       <td>resits upcoming week fail one two failed year...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>depressed</td>
#       <td>sexual orientation induced homelessness money...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>depressed</td>
#       <td>spent last school year seeing school counsell...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>depressed</td>
#       <td>suicidali born  family fights grew hometown t...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>depressed</td>
#       <td>sure exactly got honestly feel cursed god uni...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>depressed</td>
#       <td>think overdosing asapi really really cant any...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>depressed</td>
#       <td>wished make highschool  sophomore school star...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>depressed</td>
#       <td>year old guy friends lonely depressed  cannot...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>depressed</td>
#       <td>year old romaniam boy currently suffering red...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>depressed</td>
#       <td>year old sister attempted redflag friday look...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>depressed</td>
#       <td>years ago lost girlfriendfriend die suicide l...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>depressed</td>
#       <td>years ago never thought life would lowi used ...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>depressed</td>
#       <td>years old live texas honestly wanting end sin...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>depressed</td>
#       <td>years old seems like yesterday everything sti...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>depressed</td>
#       <td>years old young feel like massive failure don...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>depressed</td>
#       <td>years years</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>depressed</td>
#       <td>young die question</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>depressed</td>
#       <td>abandoned people called friends know right thi...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>depressed</td>
#       <td>abject failure barreling catastrophe bull chin...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>depressed</td>
#       <td>abomination cursei literally abomination curse...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>depressed</td>
#       <td>aborted anything myself end myselfhello all  y...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>depressed</td>
#       <td>absolute intenthello redflagwatch quite awhile...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>depressed</td>
#       <td>absolutely nothing wrong me simply choose long...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>depressed</td>
#       <td>abuse workplace seems like everyone says oh ge...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>depressed</td>
#       <td>abuseim sad step dad thing insults pushes mean...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>depressed</td>
#       <td>active community diverse interests diagnoses r...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>depressed</td>
#       <td>actually dbt bad therapy depressionmy therapis...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>depressed</td>
#       <td>actually drugs get london kill withis deepweb</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>depressed</td>
#       <td>actually feel alright thats enoughwell past ye...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>depressed</td>
#       <td>actually going follow throughi think soon im a...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>depressed</td>
#       <td>actually point livingim  struggled redflag pas...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>depressed</td>
#       <td>actually reasonive taken forever work actually...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>depressed</td>
#       <td>actually wrong redflagaside itd family course ...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>depressed</td>
#       <td>adam thanks telling cant problems dont know ho...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>depressed</td>
#       <td>adhdive diagnosed adhd school really hard me p...</td>
#       <td>[depressed]</td>
#     </tr>

# %% [markdown]
# #### View some 'not_depressed' predictions

# %%
df_bert_not_depressed = df_bert[df_bert['category'] == 'not_depressed']
df_bert_not_depressed.head(50)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>category</th>
#       <th>text</th>
#       <th>result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2805</th>
#       <td>not_depressed</td>
#       <td>yes need proof prove need start fundament...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2806</th>
#       <td>not_depressed</td>
#       <td>im still horndog reddit listening musicals b...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2807</th>
#       <td>not_depressed</td>
#       <td>already starting shitty woke damn spider dick...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2808</th>
#       <td>not_depressed</td>
#       <td>assignments core class alone feelin good</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2809</th>
#       <td>not_depressed</td>
#       <td>bbc production jane eyre starring zelah clark...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2810</th>
#       <td>not_depressed</td>
#       <td>biased muppet fan love treasure island christ...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2811</th>
#       <td>not_depressed</td>
#       <td>cool facts house cats ahhhhh oh god fyck fycj...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2812</th>
#       <td>not_depressed</td>
#       <td>days ago  days ago lost cat congestive heart ...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>2813</th>
#       <td>not_depressed</td>
#       <td>days till im oap okay maybe oap styll one yea...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2814</th>
#       <td>not_depressed</td>
#       <td>e  n bad joke</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2815</th>
#       <td>not_depressed</td>
#       <td>exams due today one first history math learni...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2816</th>
#       <td>not_depressed</td>
#       <td>females called cute took get shit scared play...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2817</th>
#       <td>not_depressed</td>
#       <td>film improvise impressions given changes know...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2818</th>
#       <td>not_depressed</td>
#       <td>followers  shitty pick lines  wtf tell</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2819</th>
#       <td>not_depressed</td>
#       <td>followers really many followers</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2820</th>
#       <td>not_depressed</td>
#       <td>left bank account new job pays biweekly means...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>2821</th>
#       <td>not_depressed</td>
#       <td>lets suspend belief moment lets stop pretendi...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2822</th>
#       <td>not_depressed</td>
#       <td>might seem like unusually high score slight f...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2823</th>
#       <td>not_depressed</td>
#       <td>minutes later got message saying downstairs a...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2824</th>
#       <td>not_depressed</td>
#       <td>movie amazing watched town next one grew up w...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2825</th>
#       <td>not_depressed</td>
#       <td>person would chuck fucker meat grinder force ...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2826</th>
#       <td>not_depressed</td>
#       <td>pm pass bedtime</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2827</th>
#       <td>not_depressed</td>
#       <td>year old likes doodlebops show seems keep att...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2828</th>
#       <td>not_depressed</td>
#       <td>year old sister watches porn found disturbing...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2829</th>
#       <td>not_depressed</td>
#       <td>year olds levelheaded adults care from politi...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2830</th>
#       <td>not_depressed</td>
#       <td>years  years since ive created reddit account...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2831</th>
#       <td>not_depressed</td>
#       <td>years old now feel good yall</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2832</th>
#       <td>not_depressed</td>
#       <td>yo boy sub still virgin idk seems like every ...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2833</th>
#       <td>not_depressed</td>
#       <td>yo girl giving advice pt  long sfw respectful...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2834</th>
#       <td>not_depressed</td>
#       <td>yorkshire boy chimneysweep falsely accused th...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2835</th>
#       <td>not_depressed</td>
#       <td>_ moments guys ever moments u wish earth would...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2836</th>
#       <td>not_depressed</td>
#       <td>a bugs life like favorite candy bar  chockfull...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2837</th>
#       <td>not_depressed</td>
#       <td>aaaaaaaa word describe feeling right made isol...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2838</th>
#       <td>not_depressed</td>
#       <td>aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa eglis...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2839</th>
#       <td>not_depressed</td>
#       <td>absolute outrage year  people still freeze cho...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2840</th>
#       <td>not_depressed</td>
#       <td>absolutely one best aviation movies times many...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2841</th>
#       <td>not_depressed</td>
#       <td>accent speaking skills around  years since mov...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2842</th>
#       <td>not_depressed</td>
#       <td>accept fact literally funny secy struggle cant</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2843</th>
#       <td>not_depressed</td>
#       <td>accepted semester summer school enough self di...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2844</th>
#       <td>not_depressed</td>
#       <td>accepting brain transplant applications tw pla...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2845</th>
#       <td>not_depressed</td>
#       <td>accidentally slept classes im really bummed gu...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2846</th>
#       <td>not_depressed</td>
#       <td>actually go la know way around played gta feel...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2847</th>
#       <td>not_depressed</td>
#       <td>actually wanna die  lot friends one exact lot ...</td>
#       <td>[depressed]</td>
#     </tr>
#     <tr>
#       <th>2848</th>
#       <td>not_depressed</td>
#       <td>adapted sam shepards play movie retains many p...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2849</th>
#       <td>not_depressed</td>
#       <td>addictive seriesi seen exact combination among...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2850</th>
#       <td>not_depressed</td>
#       <td>advice advice guy make helpful otherwise good ...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2851</th>
#       <td>not_depressed</td>
#       <td>advice boys boy  tokyo drift saw two prior pos...</td>
#       <td>[not_depressed]</td>
#     </tr>
#     <tr>
#       <th>2852</th>

# %% [markdown]
# ## Generate Scikit-learn Classification report

# %%
from sklearn.metrics import classification_report, accuracy_score

print(classification_report(df_bert.category, df_bert.result.str[0]))
# Out:
#                precision    recall  f1-score   support
#
#     depressed       0.91      0.91      0.91      2805
# not_depressed       0.91      0.91      0.91      2917
#
#      accuracy                           0.91      5722
#     macro avg       0.91      0.91      0.91      5722
#  weighted avg       0.91      0.91      0.91      5722

# %% [markdown]
# #### Create new dataframe with unlabeled text snippets to test functionality of model on previously unseen data

# %%
df_new = spark.createDataFrame([
    (1, "I'm so alone and isolated in my darkness."),
    (2, "remember that when we show consideration for others, great things can be achieved"),
    (3, "oopdeedoop beedlebob goopdeedoo pooplepoo!"),
    (4, "i am very unhappy my life is miserable no one likes me i want to be alone"),
    (5, "i went to bed early last night and got lots of sleep"),
    (6, "today wasn't bad i got some shit done and went ona nice walk"),
    (7, "Kitties and doggies snuggle up together, giving each other the love and warmth that only furry friends can provide. Their purrs and yips fill the air with joy and sweetness. Together, they make a truly wonderful pair."),
    (8, "I feel like I'm all alone in this world. No one understands me or cares about me. I just wish things were different."),
    (9, "Every sunrise brings a new possibility for creating your own happiness."),
    (10, "I just can't find the will to go on.")
]).toDF("id", "text")

# %% [markdown]
# #### See prediction results

# %%
df = loaded_model.transform(df_new).select("text", "class.result").toPandas()
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>text</th><th>result</th></tr></thead><tbody><tr><td>I'm so alone and isolated in my darkness.</td><td>List(depressed)</td></tr><tr><td>remember that when we show consideration for others, great things can be achieved</td><td>List(not_depressed)</td></tr><tr><td>oopdeedoop beedlebob goopdeedoo pooplepoo!</td><td>List(not_depressed)</td></tr><tr><td>i am very unhappy my life is miserable no one likes me i want to be alone</td><td>List(depressed)</td></tr><tr><td>i went to bed early last night and got lots of sleep</td><td>List(depressed)</td></tr><tr><td>today wasn't bad i got some shit done and went ona nice walk</td><td>List(not_depressed)</td></tr><tr><td>Kitties and doggies snuggle up together, giving each other the love and warmth that only furry friends can provide. Their purrs and yips fill the air with joy and sweetness. Together, they make a truly wonderful pair.</td><td>List(not_depressed)</td></tr><tr><td>I feel like I'm all alone in this world. No one understands me or cares about me. I just wish things were different.</td><td>List(depressed)</td></tr><tr><td>Every sunrise brings a new possibility for creating your own happiness.</td><td>List(not_depressed)</td></tr><tr><td>I just can't find the will to go on.</td><td>List(depressed)</td></tr></tbody></table></div>
